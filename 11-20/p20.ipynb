# %% [markdown]
# # Pregunta 20
# Crea una SparkSession y Explica Sus Usos.

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

# %%
spark = SparkSession.builder.appName("Pregunta20").getOrCreate()
# SparkSession -> La entrada a toda la funcionalidad de spark
# builder.appName -> asignamos el nombre de la aplicacion de spark
# getOrCreate -> crea una sesion o en su defecto utiliza una ya existente
# con la variable spark ya podemos iniciar ejecutando todo lo que iremos aprendiendo
