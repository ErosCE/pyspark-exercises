# %% [markdown]
# # Pregunta 19
# Desea leer datos de varias fuentes como CSV, JSON, Parquet.

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F 
from pyspark.sql import Window

spark = SparkSession.builder.appName("Pregunta 18").getOrCreate()

# %%
# CSV
df_csv = spark.read.csv("./datasets/restaurant_orders copy.csv", header=True, inferSchema=True)

# JSON
df_json = spark.read.json("./datasets/restaurant_orders copy.json")

# Parquet
df_parquet = spark.read.parquet("./datasets/restaurant_orders copy.parquet")
