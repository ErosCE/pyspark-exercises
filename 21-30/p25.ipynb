# %% [markdown]
# # Pregunta 25
# Desea medir la correlación lineal (Pearson) entre dos columnas numéricas en un DataFrame

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

spark = SparkSession.builder.appName('Pregunta 25').getOrCreate()

df = spark.read.csv("./datasets/employees.csv",header=True,inferSchema=True)

# %%
df.show(10)
# Lo haremos entre Age and Salary 🥸
# Out:
# +---+------------------+---+------+----------+------+------------+-----------------+----------+--------+-----------+-------+
# | ID|              Name|Age|Gender|Department|Salary|Joining Date|Performance Score|Experience|  Status|   Location|Session|
# +---+------------------+---+------+----------+------+------------+-----------------+----------+--------+-----------+-------+
# |  1|      Cory Escobar| 48|Female|        HR|  5641|  2015-05-03|              2.0|        16|  Active|   New York|  Night|
# |  2|   Timothy Sanchez| 25| Other|     Sales|  4249|  2020-11-09|              2.0|        11|Inactive|Los Angeles|Evening|
# |  3|      Chad Nichols| 57| Other|     Sales|  3058|  2019-02-12|             NULL|         1|Inactive|   New York|Morning|
# |  4|Christine Williams| 58|Female|        IT|  5895|  2017-09-08|              2.0|        13|Inactive|Los Angeles|Evening|
# ...

# %%
df.select(F.corr(F.col('Salary'),F.col('Age'))).show()
"""
# Segun la correlacion lineal el salario y la edad practiamente no hay relacion entre las variables.
# Puede deverse a muchos factores como a personas adultas sinedo malos vendedore o a jovenes en IT con suledos altos
# Se realiza este comentario porque quizas la idea comun es que mientras mas edad tengas mas podrias ganar, pero se da el caso que no es asi
"""
# Out:
# +--------------------+
# |   corr(Salary, Age)|
# +--------------------+
# |-0.03277186532058132|
# +--------------------+
# '\n# Segun la correlacion lineal el salario y la edad practiamente no hay relacion entre las variables.\n# Puede deverse a muchos factores como a personas adultas sinedo malos vendedore o a jovenes en IT con suledos altos\n# Se realiza este comentario porque quizas la idea comun es que mientras mas edad tengas mas podrias ganar, pero se da el caso que no es asi\n'
